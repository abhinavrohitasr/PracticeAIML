# %%
def generateBoard():
    print("                 ")
    print("                 ")
    print("                 ")
    print("      |      |      ")
    print("  {}   |  {}   |  {}   ".format(se , ei, ni))
    print("      |      |      ")
    print("------------------- ")
    print("      |      |      ")
    print("  {}   |  {}   |  {}   ".format(fo , fi, si))
    print("      |      |      ")
    print("------------------- ")
    print("      |      |      ")
    print("  {}   |  {}   |  {}   ".format(on , tw, th))
    print("      |      |      ")
    
def setValue(value, ptype):
    globalList = globals()
    if(value == '1'):
        if(globalList['on'] == 'X' or globalList['on'] == 'O'):
            return False
        else:
            globalList['on'] = ptype
            globalList['count'] += 1
            return True
    elif(value == '2'):
        if(globalList['tw'] == 'X' or globalList['tw'] == 'O'):
            return False
        else:
            globalList['tw'] = ptype
            globalList['count'] += 1
            return True
    elif(value == '3'):
        if(globalList['th'] == 'X' or globalList['th'] == 'O'):
            return False
        else:
            globalList['th'] = ptype
            globalList['count'] += 1
            return True
    elif(value == '4'):
        if(globalList['fo'] == 'X' or globalList['fo'] == 'O'):
            return False
        else:
            globalList['fo'] = ptype
            globalList['count'] += 1
            return True
    elif(value == '5'):
        if(globalList['fi'] == 'X' or globalList['fi'] == 'O'):
            return False
        else:
            globalList['fi'] = ptype
            globalList['count'] += 1
            return True
    elif(value == '6'):
        if(globalList['si'] == 'X' or globalList['si'] == 'O'):
            return False
        else:
            globalList['si'] = ptype
            globalList['count'] += 1
            return True
    elif(value == '7'):
        if(globalList['se'] == 'X' or globalList['se'] == 'O'):
            return False
        else:
            globalList['se'] = ptype
            globalList['count'] += 1
            return True
    elif(value == '8'):
        if(globalList['ei'] == 'X' or globalList['ei'] == 'O'):
            return False
        else:
            globalList['ei'] = ptype
            globalList['count'] += 1
            return True
    elif(value == '9'):
        if(globalList['ni'] == 'X' or globalList['ni'] == 'O'):
            return False
        else:
            globalList['ni'] = ptype
            globalList['count'] += 1
            return True
    else:
        print("Invalid Selection !")
        return False
    
def chkWin(player):
     
    if(on == tw == th == 'X'  or on == fi == ni == 'X' or on == fo == se == 'X' or tw == fi == ei == 'X' or th == si == ni == 'X' or th == fi == se == 'X' or fo == fi == si == 'X' or se == ei == ni == 'X'):
        print("{} (X) wins the game !!".format(player))
    elif(on == tw == th == 'O'  or on == fi == ni == 'O' or on == fo == se == 'O' or tw == fi == ei == 'O' or th == si == ni == 'O' or th == fi == se == 'O' or fo == fi == si == 'O' or se == ei == ni == 'O'):
        print("{} (O) wins the game !!".format(player))
    

def askValue(player, p1type, p2type):
    flag = True
    while(True):
        value = input("{} Please select positon from 1 - 9 : ".format(player))
        if(value == '0'):
            break
        if(player == "Player 1"):
            flag = setValue(value, p1type.upper())
            if(flag):
                player = "Player 2"
            else:
                print("Invalid Selection !")
            generateBoard()
        else:
            flag = setValue(value, p2type.upper())
            if(flag):
                player = "Player 1"
            else:
                print("Invalid Selection !")
            generateBoard()
        if(count == 9):
            print("Game Tie !!")
            break
        else:
            if(chkWin(player)):
                break    
            
        
    
    
p1type = ""
p2type = ""
on = tw = th = fo = fi = si = se = ei = ni = " "
count = 0
while(True):
    p1type = input("Player1 : Do you want to be X  or  O ? ")
    if(p1type.upper() == 'X'):
        p2type = "O"
        break
    elif(p1type.upper() == 'O'):
        p2type = "X"
        break
    else:
        print("Invalid Input !")
generateBoard()
if(p1type.upper() == "X"):
    askValue("Player 1" , p1type, p2type)
else:
    askValue("Player 2" , p1type, p2type)
print("Thanks !!")
# Out:
# Player1 : Do you want to be X  or  O ? x
#
#
#
#       |      |
#       |      |
#       |      |
# -------------------
#       |      |
#       |      |
#       |      |
# -------------------
#       |      |
#       |      |
#       |      |
# Player 1 Please select positon from 1 - 9 : 7
#
#
#
#       |      |
#   X   |      |
#       |      |
# -------------------
#       |      |
#       |      |
#       |      |
# -------------------
#       |      |
#       |      |
#       |      |
# Player 2 Please select positon from 1 - 9 : 4
#
#
#
#       |      |
#   X   |      |
#       |      |
# -------------------
#       |      |
#   O   |      |
#       |      |
# -------------------
#       |      |
#       |      |
#       |      |
# Player 1 Please select positon from 1 - 9 : 5
#
#
#
#       |      |
#   X   |      |
#       |      |
# -------------------
#       |      |
#   O   |  X   |
#       |      |
# -------------------
#       |      |
#       |      |
#       |      |
# ...
